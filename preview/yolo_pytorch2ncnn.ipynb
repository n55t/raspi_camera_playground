# %%
# !pip install ultralytics ncnn

# %%
#from google.colab import files
#files.upload()  # yolo11n.pt をアップロード

# %%
# !yolo export model=yolo11n.pt format=ncnn

# %%
# !zip -r yolo11n_ncnn_model.zip yolo11n_ncnn_model

# %%
from google.colab import files
files.download('yolo11n_ncnn_model.zip')
